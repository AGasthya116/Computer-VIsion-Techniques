# %% [markdown]
# # **Regularisation in PyTorch - Part 2**
# ### **Now we use a few Regularisation methods on our Fashion-MNIST CNN**
#
#   - L2 Regularisation
#   - Data Augmentation
#   - Dropout
#   - BatchNorm

# %%
# Import PyTorch
import torch
import PIL
import numpy as np

# We use torchvision to get our dataset and useful image transformations
import torchvision
import torchvision.transforms as transforms

# Import PyTorch's optimization libary and nn
# nn is used as the basic building block for our Network graphs
import torch.optim as optim
import torch.nn as nn

# Are we using our GPU?
print("GPU available: {}".format(torch.cuda.is_available()))
# Out:
# GPU available: True

# %%
device = 'cuda' #'cpu' if no GPU available

# %% [markdown]
# # **2. Building a CNN with Regulisation**
# ## **Implementing Data Augmentation**
#
# #### **Understanding What Our Transforms Do**
#
# 1. Our Transforms are applied to an image or batch of images everytime it's loaded.
# 2. These new images aren't saved, they're generated or 'altered' everytime a batch is loaded

# %%
data_transforms = {
    'train': transforms.Compose([
        # Note these are executed in the order they are called here
        # Some of these transforms return a color image, hence why we need to convert
        # the image back to grayscale
        transforms.RandomAffine(degrees = 10, translate = (0.05,0.05), shear = 5), 
        transforms.ColorJitter(hue = .05, saturation = .05),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),# resample = PIL.Image.BILINEAR),
        transforms.Grayscale(num_output_channels = 1),
        transforms.ToTensor(),
        transforms.Normalize((0.5, ), (0.5, )),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, ), (0.5, ))
    ])
}

# %% [markdown]
# ### **Fetch and Create our Data Loaders**

# %%
# Load our Train Data and specify what transform to use when loading
trainset = torchvision.datasets.FashionMNIST(root='./', train=True,
                                        download=False, transform=data_transforms['train'])

# Load our Test Data and specify what transform to use when loading
testset = torchvision.datasets.FashionMNIST(root='./', train=False,
                                       download=False, transform=data_transforms['val'])

# Prepare train and test loader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

# %% [markdown]
# ### **Adding Dropout**
#
# In Convolutional Neural Networks Dropout is commonly added after CONV-RELU Layers.
#
# E.g. CONV->RELU->**DROPOUT**
#
# #### **Dropout Recommendations**
#
# In CNN's values of 0.1 to 0.3 have been found to work well.
#
# ### **Adding BatchNorm**
#
# In CNNs **BatchNorm** is best used between the Conv Layer and the activation function layer (ReLU)
# When used with Dropout, the recommended order is:
#
# CONV_1 -> **BatchNorm** -> ReLU -> Dropout - CONV_2
#
# **NOTE** BatchNorm's input arguement is the **output** size of the previous layer.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        # Adding BatchNorm, using 32 as the input since 32 was the output of our first Conv layer
        self.conv1_bn = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 3)
        # Adding BatchNorm, using 64 as the input since 64 was the output of our first Conv layer
        self.conv2_bn = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)
        # Defining our dropout function with a rate of 0.2
        # We can apply this after any layer, but it's best suited after ReLU
        self.dropOut = nn.Dropout(0.2)

    def forward(self, x):
        x = F.relu(self.conv1_bn(self.conv1(x)))
        x = self.dropOut(x)
        x = self.dropOut(F.relu(self.conv2_bn(self.conv2(x))))

        x = self.pool(x)
        x = x.view(-1, 64 * 12 * 12)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (dropOut): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ### **Adding L2 Regularisation**
#
#
# L2 regularisation on the parameters/weights of the model is directly included in most optimizers, including optim.SGD.
#
# It can be controlled with the **weight_decay** parameter as can be seen in the [SGD documentation](http://pytorch.org/docs/optim.html#torch.optim.SGD).
#
# ```weight_decay``` (**float**, optional) – weight decay *(L2 penalty) (default: 0)*
#
# **Good L2 Values range from 0.1 to 0.0001**
#
# **NOTE:**
#
#  L1 regularization is not included by default in the optimizers, but could be added by including an extra loss nn.L1Loss in the weights of the model.

# %%
# We import our optimizer function
import torch.optim as optim

# We use Cross Entropy Loss as our loss function
criterion = nn.CrossEntropyLoss()

# For our gradient descent algorthim or Optimizer
# We use Stochastic Gradient Descent (SGD) with a learning rate of 0.001
# We set the momentum to be 0.9
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay = 0.001)

# %% [markdown]
# # **Training Our Model Using Regulisation Methods - Data Augmentation, Dropout, BatchNorm & L2 Regularisation**

# %%
# We loop over the traing dataset multiple times (each time is called an epoch)
epochs = 15

# Create some empty arrays to store logs 
epoch_log = []
loss_log = []
accuracy_log = []

# Iterate for a specified number of epochs
for epoch in range(epochs):  
    print(f'Starting Epoch: {epoch+1}...')

    # We keep adding or accumulating our loss after each mini-batch in running_loss
    running_loss = 0.0

    # We iterate through our trainloader iterator
    # Each cycle is a minibatch
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # Move our data to GPU
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Clear the gradients before training by setting to zero
        # Required for a fresh start
        optimizer.zero_grad()

        # Forward -> backprop + optimize
        outputs = net(inputs) # Forward Propagation 
        loss = criterion(outputs, labels) # Get Loss (quantify the difference between the results and predictions)
        loss.backward() # Back propagate to obtain the new gradients for all nodes
        optimizer.step() # Update the gradients/weights

        # Print Training statistics - Epoch/Iterations/Loss/Accurachy
        running_loss += loss.item()
        if i % 100 == 99:    # show our loss every 50 mini-batches
            correct = 0 # Initialize our variable to hold the count for the correct predictions
            total = 0 # Initialize our variable to hold the count of the number of labels iterated

            # We don't need gradients for validation, so wrap in 
            # no_grad to save memory
            with torch.no_grad():
                # Iterate through the testloader iterator
                for data in testloader:
                    images, labels = data
                    # Move our data to GPU
                    images = images.to(device)
                    labels = labels.to(device)
                    
                    # Foward propagate our test data batch through our model
                    outputs = net(images)

                     # Get predictions from the maximum value
                    _, predicted = torch.max(outputs.data, 1)
                    # Keep adding the label size or length to the total variable
                    total += labels.size(0)
                    # Keep a running total of the number of predictions predicted correctly
                    correct += (predicted == labels).sum().item()

                accuracy = 100 * correct / total
                epoch_num = epoch + 1
                actual_loss = running_loss / 50
                print(f'Epoch: {epoch_num}, Mini-Batches Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%')
                running_loss = 0.0

    # Store training stats after each epoch
    epoch_log.append(epoch_num)
    loss_log.append(actual_loss)
    accuracy_log.append(accuracy)

print('Finished Training')
# Out:
# Starting Epoch: 1...
# Epoch: 1, Mini-Batches Completed: 100, Loss: 2.618, Test Accuracy = 71.500%
# Epoch: 1, Mini-Batches Completed: 200, Loss: 1.696, Test Accuracy = 74.500%
# Epoch: 1, Mini-Batches Completed: 300, Loss: 1.480, Test Accuracy = 75.720%
# Epoch: 1, Mini-Batches Completed: 400, Loss: 1.391, Test Accuracy = 76.390%
# Epoch: 1, Mini-Batches Completed: 500, Loss: 1.332, Test Accuracy = 78.310%
# Epoch: 1, Mini-Batches Completed: 600, Loss: 1.345, Test Accuracy = 78.780%
# Epoch: 1, Mini-Batches Completed: 700, Loss: 1.334, Test Accuracy = 76.170%
# Epoch: 1, Mini-Batches Completed: 800, Loss: 1.265, Test Accuracy = 79.480%
# Epoch: 1, Mini-Batches Completed: 900, Loss: 1.220, Test Accuracy = 79.810%
# Epoch: 1, Mini-Batches Completed: 1000, Loss: 1.195, Test Accuracy = 80.380%
# Epoch: 1, Mini-Batches Completed: 1100, Loss: 1.186, Test Accuracy = 79.300%
# Epoch: 1, Mini-Batches Completed: 1200, Loss: 1.198, Test Accuracy = 81.330%
# Epoch: 1, Mini-Batches Completed: 1300, Loss: 1.078, Test Accuracy = 82.230%
# Epoch: 1, Mini-Batches Completed: 1400, Loss: 1.093, Test Accuracy = 82.310%
# Epoch: 1, Mini-Batches Completed: 1500, Loss: 1.147, Test Accuracy = 81.080%
# Epoch: 1, Mini-Batches Completed: 1600, Loss: 1.107, Test Accuracy = 82.270%
# Epoch: 1, Mini-Batches Completed: 1700, Loss: 1.070, Test Accuracy = 82.470%
# Epoch: 1, Mini-Batches Completed: 1800, Loss: 1.018, Test Accuracy = 82.750%
# Starting Epoch: 2...
# Epoch: 2, Mini-Batches Completed: 100, Loss: 1.062, Test Accuracy = 80.440%
# Epoch: 2, Mini-Batches Completed: 200, Loss: 1.103, Test Accuracy = 82.710%
# Epoch: 2, Mini-Batches Completed: 300, Loss: 1.068, Test Accuracy = 83.840%
# Epoch: 2, Mini-Batches Completed: 400, Loss: 1.005, Test Accuracy = 84.430%
# Epoch: 2, Mini-Batches Completed: 500, Loss: 0.995, Test Accuracy = 83.780%
# Epoch: 2, Mini-Batches Completed: 600, Loss: 0.994, Test Accuracy = 84.220%
# Epoch: 2, Mini-Batches Completed: 700, Loss: 0.973, Test Accuracy = 83.340%
# Epoch: 2, Mini-Batches Completed: 800, Loss: 1.003, Test Accuracy = 83.410%
# Epoch: 2, Mini-Batches Completed: 900, Loss: 0.937, Test Accuracy = 83.490%
# Epoch: 2, Mini-Batches Completed: 1000, Loss: 0.926, Test Accuracy = 82.500%
# Epoch: 2, Mini-Batches Completed: 1100, Loss: 0.952, Test Accuracy = 84.670%
# Epoch: 2, Mini-Batches Completed: 1200, Loss: 0.986, Test Accuracy = 84.880%
# Epoch: 2, Mini-Batches Completed: 1300, Loss: 0.966, Test Accuracy = 83.800%
# Epoch: 2, Mini-Batches Completed: 1400, Loss: 0.974, Test Accuracy = 84.350%
# Epoch: 2, Mini-Batches Completed: 1500, Loss: 0.956, Test Accuracy = 85.450%
# Epoch: 2, Mini-Batches Completed: 1600, Loss: 0.989, Test Accuracy = 85.200%
# Epoch: 2, Mini-Batches Completed: 1700, Loss: 0.934, Test Accuracy = 85.630%
# Epoch: 2, Mini-Batches Completed: 1800, Loss: 0.924, Test Accuracy = 85.190%
# Starting Epoch: 3...
# Epoch: 3, Mini-Batches Completed: 100, Loss: 0.900, Test Accuracy = 84.550%
# Epoch: 3, Mini-Batches Completed: 200, Loss: 0.898, Test Accuracy = 85.330%
# Epoch: 3, Mini-Batches Completed: 300, Loss: 0.865, Test Accuracy = 85.350%
# Epoch: 3, Mini-Batches Completed: 400, Loss: 0.852, Test Accuracy = 85.720%
# Epoch: 3, Mini-Batches Completed: 500, Loss: 0.912, Test Accuracy = 85.130%
# Epoch: 3, Mini-Batches Completed: 600, Loss: 0.880, Test Accuracy = 85.840%
# Epoch: 3, Mini-Batches Completed: 700, Loss: 0.928, Test Accuracy = 85.990%
# Epoch: 3, Mini-Batches Completed: 800, Loss: 0.907, Test Accuracy = 85.210%
# Epoch: 3, Mini-Batches Completed: 900, Loss: 0.883, Test Accuracy = 84.510%
# Epoch: 3, Mini-Batches Completed: 1000, Loss: 0.947, Test Accuracy = 86.390%
# Epoch: 3, Mini-Batches Completed: 1100, Loss: 0.887, Test Accuracy = 85.650%
# Epoch: 3, Mini-Batches Completed: 1200, Loss: 0.879, Test Accuracy = 86.700%
# Epoch: 3, Mini-Batches Completed: 1300, Loss: 0.871, Test Accuracy = 85.950%
# Epoch: 3, Mini-Batches Completed: 1400, Loss: 0.861, Test Accuracy = 86.030%
# Epoch: 3, Mini-Batches Completed: 1500, Loss: 0.909, Test Accuracy = 86.830%
# Epoch: 3, Mini-Batches Completed: 1600, Loss: 0.877, Test Accuracy = 86.340%
# Epoch: 3, Mini-Batches Completed: 1700, Loss: 0.845, Test Accuracy = 85.490%
# Epoch: 3, Mini-Batches Completed: 1800, Loss: 0.900, Test Accuracy = 85.850%
# Starting Epoch: 4...
# Epoch: 4, Mini-Batches Completed: 100, Loss: 0.879, Test Accuracy = 85.770%
# Epoch: 4, Mini-Batches Completed: 200, Loss: 0.845, Test Accuracy = 86.060%
# Epoch: 4, Mini-Batches Completed: 300, Loss: 0.885, Test Accuracy = 86.250%
# Epoch: 4, Mini-Batches Completed: 400, Loss: 0.781, Test Accuracy = 85.620%
# Epoch: 4, Mini-Batches Completed: 500, Loss: 0.859, Test Accuracy = 86.370%
# Epoch: 4, Mini-Batches Completed: 600, Loss: 0.834, Test Accuracy = 87.230%
# Epoch: 4, Mini-Batches Completed: 700, Loss: 0.832, Test Accuracy = 85.990%
# Epoch: 4, Mini-Batches Completed: 800, Loss: 0.862, Test Accuracy = 86.500%
# Epoch: 4, Mini-Batches Completed: 900, Loss: 0.771, Test Accuracy = 86.630%
# Epoch: 4, Mini-Batches Completed: 1000, Loss: 0.798, Test Accuracy = 86.360%
# Epoch: 4, Mini-Batches Completed: 1100, Loss: 0.829, Test Accuracy = 86.350%
# Epoch: 4, Mini-Batches Completed: 1200, Loss: 0.815, Test Accuracy = 86.810%
# Epoch: 4, Mini-Batches Completed: 1300, Loss: 0.790, Test Accuracy = 87.100%
# Epoch: 4, Mini-Batches Completed: 1400, Loss: 0.850, Test Accuracy = 83.190%
# Epoch: 4, Mini-Batches Completed: 1500, Loss: 0.844, Test Accuracy = 86.610%
# Epoch: 4, Mini-Batches Completed: 1600, Loss: 0.790, Test Accuracy = 85.870%
# Epoch: 4, Mini-Batches Completed: 1700, Loss: 0.815, Test Accuracy = 86.850%
# Epoch: 4, Mini-Batches Completed: 1800, Loss: 0.819, Test Accuracy = 87.040%
# Starting Epoch: 5...
# Epoch: 5, Mini-Batches Completed: 100, Loss: 0.837, Test Accuracy = 86.860%
# Epoch: 5, Mini-Batches Completed: 200, Loss: 0.801, Test Accuracy = 87.240%
# Epoch: 5, Mini-Batches Completed: 300, Loss: 0.777, Test Accuracy = 86.910%
# Epoch: 5, Mini-Batches Completed: 400, Loss: 0.787, Test Accuracy = 87.570%
# Epoch: 5, Mini-Batches Completed: 500, Loss: 0.777, Test Accuracy = 87.780%
# Epoch: 5, Mini-Batches Completed: 600, Loss: 0.817, Test Accuracy = 87.090%
# Epoch: 5, Mini-Batches Completed: 700, Loss: 0.771, Test Accuracy = 87.580%
# Epoch: 5, Mini-Batches Completed: 800, Loss: 0.783, Test Accuracy = 87.370%
# Epoch: 5, Mini-Batches Completed: 900, Loss: 0.763, Test Accuracy = 87.220%
# Epoch: 5, Mini-Batches Completed: 1000, Loss: 0.854, Test Accuracy = 87.210%
# Epoch: 5, Mini-Batches Completed: 1100, Loss: 0.812, Test Accuracy = 87.450%
# Epoch: 5, Mini-Batches Completed: 1200, Loss: 0.802, Test Accuracy = 87.400%
# Epoch: 5, Mini-Batches Completed: 1300, Loss: 0.788, Test Accuracy = 87.620%
# Epoch: 5, Mini-Batches Completed: 1400, Loss: 0.792, Test Accuracy = 87.340%
# Epoch: 5, Mini-Batches Completed: 1500, Loss: 0.787, Test Accuracy = 86.690%
# Epoch: 5, Mini-Batches Completed: 1600, Loss: 0.812, Test Accuracy = 87.710%
# Epoch: 5, Mini-Batches Completed: 1700, Loss: 0.740, Test Accuracy = 87.540%
# Epoch: 5, Mini-Batches Completed: 1800, Loss: 0.768, Test Accuracy = 86.250%
# Starting Epoch: 6...
# Epoch: 6, Mini-Batches Completed: 100, Loss: 0.815, Test Accuracy = 85.930%
# Epoch: 6, Mini-Batches Completed: 200, Loss: 0.739, Test Accuracy = 86.540%
# Epoch: 6, Mini-Batches Completed: 300, Loss: 0.792, Test Accuracy = 87.560%
# Epoch: 6, Mini-Batches Completed: 400, Loss: 0.721, Test Accuracy = 87.580%
# Epoch: 6, Mini-Batches Completed: 500, Loss: 0.754, Test Accuracy = 87.780%
# Epoch: 6, Mini-Batches Completed: 600, Loss: 0.717, Test Accuracy = 85.990%
# Epoch: 6, Mini-Batches Completed: 700, Loss: 0.792, Test Accuracy = 87.180%
# Epoch: 6, Mini-Batches Completed: 800, Loss: 0.736, Test Accuracy = 86.500%
# Epoch: 6, Mini-Batches Completed: 900, Loss: 0.857, Test Accuracy = 86.250%
# Epoch: 6, Mini-Batches Completed: 1000, Loss: 0.761, Test Accuracy = 87.560%
# Epoch: 6, Mini-Batches Completed: 1100, Loss: 0.747, Test Accuracy = 87.120%
# Epoch: 6, Mini-Batches Completed: 1200, Loss: 0.744, Test Accuracy = 87.240%
# Epoch: 6, Mini-Batches Completed: 1300, Loss: 0.761, Test Accuracy = 87.110%
# Epoch: 6, Mini-Batches Completed: 1400, Loss: 0.767, Test Accuracy = 87.530%
# Epoch: 6, Mini-Batches Completed: 1500, Loss: 0.754, Test Accuracy = 88.000%
# Epoch: 6, Mini-Batches Completed: 1600, Loss: 0.765, Test Accuracy = 87.780%
# Epoch: 6, Mini-Batches Completed: 1700, Loss: 0.773, Test Accuracy = 87.630%
# Epoch: 6, Mini-Batches Completed: 1800, Loss: 0.726, Test Accuracy = 87.820%
# Starting Epoch: 7...
# Epoch: 7, Mini-Batches Completed: 100, Loss: 0.740, Test Accuracy = 87.720%
# Epoch: 7, Mini-Batches Completed: 200, Loss: 0.738, Test Accuracy = 87.390%
# Epoch: 7, Mini-Batches Completed: 300, Loss: 0.744, Test Accuracy = 87.660%
# Epoch: 7, Mini-Batches Completed: 400, Loss: 0.773, Test Accuracy = 88.070%
# Epoch: 7, Mini-Batches Completed: 500, Loss: 0.732, Test Accuracy = 88.000%
# Epoch: 7, Mini-Batches Completed: 600, Loss: 0.747, Test Accuracy = 88.240%
# Epoch: 7, Mini-Batches Completed: 700, Loss: 0.790, Test Accuracy = 88.310%
# Epoch: 7, Mini-Batches Completed: 800, Loss: 0.696, Test Accuracy = 88.060%
# Epoch: 7, Mini-Batches Completed: 900, Loss: 0.732, Test Accuracy = 88.030%
# Epoch: 7, Mini-Batches Completed: 1000, Loss: 0.753, Test Accuracy = 88.160%
# Epoch: 7, Mini-Batches Completed: 1100, Loss: 0.724, Test Accuracy = 86.460%
# Epoch: 7, Mini-Batches Completed: 1200, Loss: 0.755, Test Accuracy = 88.230%
# Epoch: 7, Mini-Batches Completed: 1300, Loss: 0.748, Test Accuracy = 87.910%
# Epoch: 7, Mini-Batches Completed: 1400, Loss: 0.780, Test Accuracy = 87.940%
# Epoch: 7, Mini-Batches Completed: 1500, Loss: 0.715, Test Accuracy = 88.100%
# Epoch: 7, Mini-Batches Completed: 1600, Loss: 0.700, Test Accuracy = 87.960%
# Epoch: 7, Mini-Batches Completed: 1700, Loss: 0.721, Test Accuracy = 88.130%
# Epoch: 7, Mini-Batches Completed: 1800, Loss: 0.750, Test Accuracy = 88.400%
# Starting Epoch: 8...
# Epoch: 8, Mini-Batches Completed: 100, Loss: 0.743, Test Accuracy = 88.280%
# Epoch: 8, Mini-Batches Completed: 200, Loss: 0.751, Test Accuracy = 88.540%
# Epoch: 8, Mini-Batches Completed: 300, Loss: 0.728, Test Accuracy = 88.440%
# Epoch: 8, Mini-Batches Completed: 400, Loss: 0.709, Test Accuracy = 87.900%
# Epoch: 8, Mini-Batches Completed: 500, Loss: 0.682, Test Accuracy = 87.950%
# Epoch: 8, Mini-Batches Completed: 600, Loss: 0.702, Test Accuracy = 88.150%
# Epoch: 8, Mini-Batches Completed: 700, Loss: 0.719, Test Accuracy = 88.010%
# Epoch: 8, Mini-Batches Completed: 800, Loss: 0.740, Test Accuracy = 88.520%
# Epoch: 8, Mini-Batches Completed: 900, Loss: 0.750, Test Accuracy = 88.350%
# Epoch: 8, Mini-Batches Completed: 1000, Loss: 0.722, Test Accuracy = 88.300%
# Epoch: 8, Mini-Batches Completed: 1100, Loss: 0.675, Test Accuracy = 87.460%
# Epoch: 8, Mini-Batches Completed: 1200, Loss: 0.688, Test Accuracy = 88.260%
# Epoch: 8, Mini-Batches Completed: 1300, Loss: 0.713, Test Accuracy = 88.480%
# Epoch: 8, Mini-Batches Completed: 1400, Loss: 0.758, Test Accuracy = 88.470%
# Epoch: 8, Mini-Batches Completed: 1500, Loss: 0.742, Test Accuracy = 87.980%
# Epoch: 8, Mini-Batches Completed: 1600, Loss: 0.716, Test Accuracy = 88.580%
# Epoch: 8, Mini-Batches Completed: 1700, Loss: 0.701, Test Accuracy = 87.880%
# Epoch: 8, Mini-Batches Completed: 1800, Loss: 0.734, Test Accuracy = 88.580%
# Starting Epoch: 9...
# Epoch: 9, Mini-Batches Completed: 100, Loss: 0.709, Test Accuracy = 88.620%
# Epoch: 9, Mini-Batches Completed: 200, Loss: 0.711, Test Accuracy = 88.080%
# Epoch: 9, Mini-Batches Completed: 300, Loss: 0.724, Test Accuracy = 88.380%
# Epoch: 9, Mini-Batches Completed: 400, Loss: 0.682, Test Accuracy = 86.730%
# Epoch: 9, Mini-Batches Completed: 500, Loss: 0.701, Test Accuracy = 88.570%
# Epoch: 9, Mini-Batches Completed: 600, Loss: 0.708, Test Accuracy = 87.010%
# Epoch: 9, Mini-Batches Completed: 700, Loss: 0.688, Test Accuracy = 88.230%
# Epoch: 9, Mini-Batches Completed: 800, Loss: 0.711, Test Accuracy = 87.210%
# Epoch: 9, Mini-Batches Completed: 900, Loss: 0.670, Test Accuracy = 88.750%
# Epoch: 9, Mini-Batches Completed: 1000, Loss: 0.683, Test Accuracy = 88.820%
# Epoch: 9, Mini-Batches Completed: 1100, Loss: 0.651, Test Accuracy = 88.310%
# Epoch: 9, Mini-Batches Completed: 1200, Loss: 0.692, Test Accuracy = 88.640%
# Epoch: 9, Mini-Batches Completed: 1300, Loss: 0.674, Test Accuracy = 89.090%
# Epoch: 9, Mini-Batches Completed: 1400, Loss: 0.705, Test Accuracy = 88.100%
# Epoch: 9, Mini-Batches Completed: 1500, Loss: 0.728, Test Accuracy = 89.160%
# Epoch: 9, Mini-Batches Completed: 1600, Loss: 0.680, Test Accuracy = 88.830%
# Epoch: 9, Mini-Batches Completed: 1700, Loss: 0.693, Test Accuracy = 88.600%
# Epoch: 9, Mini-Batches Completed: 1800, Loss: 0.730, Test Accuracy = 88.290%
# Starting Epoch: 10...
# Epoch: 10, Mini-Batches Completed: 100, Loss: 0.643, Test Accuracy = 88.840%
# Epoch: 10, Mini-Batches Completed: 200, Loss: 0.653, Test Accuracy = 88.760%
# Epoch: 10, Mini-Batches Completed: 300, Loss: 0.678, Test Accuracy = 87.420%
# Epoch: 10, Mini-Batches Completed: 400, Loss: 0.747, Test Accuracy = 88.550%
# Epoch: 10, Mini-Batches Completed: 500, Loss: 0.700, Test Accuracy = 88.830%
# Epoch: 10, Mini-Batches Completed: 600, Loss: 0.722, Test Accuracy = 88.570%
# Epoch: 10, Mini-Batches Completed: 700, Loss: 0.690, Test Accuracy = 88.650%
# Epoch: 10, Mini-Batches Completed: 800, Loss: 0.702, Test Accuracy = 89.320%
# Epoch: 10, Mini-Batches Completed: 900, Loss: 0.680, Test Accuracy = 89.300%
# Epoch: 10, Mini-Batches Completed: 1000, Loss: 0.709, Test Accuracy = 88.550%
# Epoch: 10, Mini-Batches Completed: 1100, Loss: 0.660, Test Accuracy = 89.120%
# Epoch: 10, Mini-Batches Completed: 1200, Loss: 0.717, Test Accuracy = 89.160%
# Epoch: 10, Mini-Batches Completed: 1300, Loss: 0.680, Test Accuracy = 88.840%
# Epoch: 10, Mini-Batches Completed: 1400, Loss: 0.672, Test Accuracy = 89.110%
# Epoch: 10, Mini-Batches Completed: 1500, Loss: 0.672, Test Accuracy = 88.830%
# Epoch: 10, Mini-Batches Completed: 1600, Loss: 0.625, Test Accuracy = 87.970%
# Epoch: 10, Mini-Batches Completed: 1700, Loss: 0.687, Test Accuracy = 88.710%
# Epoch: 10, Mini-Batches Completed: 1800, Loss: 0.718, Test Accuracy = 88.840%
# Starting Epoch: 11...
# Epoch: 11, Mini-Batches Completed: 100, Loss: 0.632, Test Accuracy = 89.010%
# Epoch: 11, Mini-Batches Completed: 200, Loss: 0.683, Test Accuracy = 87.690%
# Epoch: 11, Mini-Batches Completed: 300, Loss: 0.625, Test Accuracy = 88.800%
# Epoch: 11, Mini-Batches Completed: 400, Loss: 0.652, Test Accuracy = 89.350%
# Epoch: 11, Mini-Batches Completed: 500, Loss: 0.655, Test Accuracy = 89.130%
# Epoch: 11, Mini-Batches Completed: 600, Loss: 0.693, Test Accuracy = 89.090%
# Epoch: 11, Mini-Batches Completed: 700, Loss: 0.675, Test Accuracy = 88.760%
# Epoch: 11, Mini-Batches Completed: 800, Loss: 0.708, Test Accuracy = 88.940%
# Epoch: 11, Mini-Batches Completed: 900, Loss: 0.676, Test Accuracy = 88.960%
# Epoch: 11, Mini-Batches Completed: 1000, Loss: 0.690, Test Accuracy = 88.940%
# Epoch: 11, Mini-Batches Completed: 1100, Loss: 0.699, Test Accuracy = 89.020%
# Epoch: 11, Mini-Batches Completed: 1200, Loss: 0.727, Test Accuracy = 88.760%
# Epoch: 11, Mini-Batches Completed: 1300, Loss: 0.647, Test Accuracy = 89.430%
# Epoch: 11, Mini-Batches Completed: 1400, Loss: 0.649, Test Accuracy = 88.690%
# Epoch: 11, Mini-Batches Completed: 1500, Loss: 0.680, Test Accuracy = 88.730%
# Epoch: 11, Mini-Batches Completed: 1600, Loss: 0.709, Test Accuracy = 88.980%
# Epoch: 11, Mini-Batches Completed: 1700, Loss: 0.683, Test Accuracy = 88.310%
# Epoch: 11, Mini-Batches Completed: 1800, Loss: 0.674, Test Accuracy = 89.050%
# Starting Epoch: 12...
# Epoch: 12, Mini-Batches Completed: 100, Loss: 0.654, Test Accuracy = 89.060%
# Epoch: 12, Mini-Batches Completed: 200, Loss: 0.634, Test Accuracy = 88.930%
# Epoch: 12, Mini-Batches Completed: 300, Loss: 0.651, Test Accuracy = 89.260%
# Epoch: 12, Mini-Batches Completed: 400, Loss: 0.680, Test Accuracy = 88.960%
# Epoch: 12, Mini-Batches Completed: 500, Loss: 0.706, Test Accuracy = 88.720%
# Epoch: 12, Mini-Batches Completed: 600, Loss: 0.659, Test Accuracy = 89.250%
# Epoch: 12, Mini-Batches Completed: 700, Loss: 0.650, Test Accuracy = 89.340%
# Epoch: 12, Mini-Batches Completed: 800, Loss: 0.650, Test Accuracy = 89.530%
# Epoch: 12, Mini-Batches Completed: 900, Loss: 0.625, Test Accuracy = 89.000%
# Epoch: 12, Mini-Batches Completed: 1000, Loss: 0.642, Test Accuracy = 89.060%
# Epoch: 12, Mini-Batches Completed: 1100, Loss: 0.663, Test Accuracy = 88.410%
# Epoch: 12, Mini-Batches Completed: 1200, Loss: 0.704, Test Accuracy = 89.230%
# Epoch: 12, Mini-Batches Completed: 1300, Loss: 0.621, Test Accuracy = 89.360%
# Epoch: 12, Mini-Batches Completed: 1400, Loss: 0.686, Test Accuracy = 88.880%
# Epoch: 12, Mini-Batches Completed: 1500, Loss: 0.684, Test Accuracy = 88.830%
# Epoch: 12, Mini-Batches Completed: 1600, Loss: 0.647, Test Accuracy = 89.350%
# Epoch: 12, Mini-Batches Completed: 1700, Loss: 0.680, Test Accuracy = 88.900%
# Epoch: 12, Mini-Batches Completed: 1800, Loss: 0.648, Test Accuracy = 88.580%
# Starting Epoch: 13...
# Epoch: 13, Mini-Batches Completed: 100, Loss: 0.639, Test Accuracy = 88.700%
# Epoch: 13, Mini-Batches Completed: 200, Loss: 0.674, Test Accuracy = 89.750%
# Epoch: 13, Mini-Batches Completed: 300, Loss: 0.685, Test Accuracy = 88.800%
# Epoch: 13, Mini-Batches Completed: 400, Loss: 0.602, Test Accuracy = 89.360%
# Epoch: 13, Mini-Batches Completed: 500, Loss: 0.631, Test Accuracy = 89.050%
# Epoch: 13, Mini-Batches Completed: 600, Loss: 0.661, Test Accuracy = 89.710%
# Epoch: 13, Mini-Batches Completed: 700, Loss: 0.698, Test Accuracy = 89.100%
# Epoch: 13, Mini-Batches Completed: 800, Loss: 0.668, Test Accuracy = 89.190%
# Epoch: 13, Mini-Batches Completed: 900, Loss: 0.659, Test Accuracy = 87.930%
# Epoch: 13, Mini-Batches Completed: 1000, Loss: 0.692, Test Accuracy = 89.390%
# Epoch: 13, Mini-Batches Completed: 1100, Loss: 0.642, Test Accuracy = 89.400%
# Epoch: 13, Mini-Batches Completed: 1200, Loss: 0.624, Test Accuracy = 89.140%
# Epoch: 13, Mini-Batches Completed: 1300, Loss: 0.609, Test Accuracy = 89.210%
# Epoch: 13, Mini-Batches Completed: 1400, Loss: 0.641, Test Accuracy = 88.790%
# Epoch: 13, Mini-Batches Completed: 1500, Loss: 0.624, Test Accuracy = 89.300%
# Epoch: 13, Mini-Batches Completed: 1600, Loss: 0.656, Test Accuracy = 88.710%
# Epoch: 13, Mini-Batches Completed: 1700, Loss: 0.646, Test Accuracy = 89.220%
# Epoch: 13, Mini-Batches Completed: 1800, Loss: 0.596, Test Accuracy = 89.250%
# Starting Epoch: 14...
# Epoch: 14, Mini-Batches Completed: 100, Loss: 0.625, Test Accuracy = 89.060%
# Epoch: 14, Mini-Batches Completed: 200, Loss: 0.622, Test Accuracy = 89.250%
# Epoch: 14, Mini-Batches Completed: 300, Loss: 0.674, Test Accuracy = 89.630%
# Epoch: 14, Mini-Batches Completed: 400, Loss: 0.614, Test Accuracy = 89.080%
# Epoch: 14, Mini-Batches Completed: 500, Loss: 0.633, Test Accuracy = 89.680%
# Epoch: 14, Mini-Batches Completed: 600, Loss: 0.632, Test Accuracy = 89.740%
# Epoch: 14, Mini-Batches Completed: 700, Loss: 0.591, Test Accuracy = 89.160%
# Epoch: 14, Mini-Batches Completed: 800, Loss: 0.615, Test Accuracy = 89.490%
# Epoch: 14, Mini-Batches Completed: 900, Loss: 0.599, Test Accuracy = 89.480%
# Epoch: 14, Mini-Batches Completed: 1000, Loss: 0.634, Test Accuracy = 89.580%
# Epoch: 14, Mini-Batches Completed: 1100, Loss: 0.650, Test Accuracy = 89.310%
# Epoch: 14, Mini-Batches Completed: 1200, Loss: 0.698, Test Accuracy = 89.540%
# Epoch: 14, Mini-Batches Completed: 1300, Loss: 0.660, Test Accuracy = 89.360%
# Epoch: 14, Mini-Batches Completed: 1400, Loss: 0.670, Test Accuracy = 89.340%
# Epoch: 14, Mini-Batches Completed: 1500, Loss: 0.637, Test Accuracy = 89.660%
# Epoch: 14, Mini-Batches Completed: 1600, Loss: 0.644, Test Accuracy = 89.270%
# Epoch: 14, Mini-Batches Completed: 1700, Loss: 0.683, Test Accuracy = 89.900%
# Epoch: 14, Mini-Batches Completed: 1800, Loss: 0.634, Test Accuracy = 89.800%
# Starting Epoch: 15...
# Epoch: 15, Mini-Batches Completed: 100, Loss: 0.622, Test Accuracy = 89.940%
# Epoch: 15, Mini-Batches Completed: 200, Loss: 0.665, Test Accuracy = 89.860%
# Epoch: 15, Mini-Batches Completed: 300, Loss: 0.624, Test Accuracy = 89.660%
# Epoch: 15, Mini-Batches Completed: 400, Loss: 0.627, Test Accuracy = 89.460%
# Epoch: 15, Mini-Batches Completed: 500, Loss: 0.615, Test Accuracy = 89.660%
# Epoch: 15, Mini-Batches Completed: 600, Loss: 0.673, Test Accuracy = 89.470%
# Epoch: 15, Mini-Batches Completed: 700, Loss: 0.588, Test Accuracy = 89.280%
# Epoch: 15, Mini-Batches Completed: 800, Loss: 0.649, Test Accuracy = 89.920%
# Epoch: 15, Mini-Batches Completed: 900, Loss: 0.670, Test Accuracy = 89.940%
# Epoch: 15, Mini-Batches Completed: 1000, Loss: 0.646, Test Accuracy = 89.540%
# Epoch: 15, Mini-Batches Completed: 1100, Loss: 0.615, Test Accuracy = 88.820%
# Epoch: 15, Mini-Batches Completed: 1200, Loss: 0.612, Test Accuracy = 88.690%
# Epoch: 15, Mini-Batches Completed: 1300, Loss: 0.634, Test Accuracy = 89.240%
# Epoch: 15, Mini-Batches Completed: 1400, Loss: 0.612, Test Accuracy = 89.570%
# Epoch: 15, Mini-Batches Completed: 1500, Loss: 0.611, Test Accuracy = 89.410%
# Epoch: 15, Mini-Batches Completed: 1600, Loss: 0.657, Test Accuracy = 89.020%
# Epoch: 15, Mini-Batches Completed: 1700, Loss: 0.653, Test Accuracy = 89.220%
# Epoch: 15, Mini-Batches Completed: 1800, Loss: 0.594, Test Accuracy = 89.940%
# Finished Training

# %% [markdown]
# ### **Model Accuracy**

# %%
correct = 0 
total = 0

with torch.no_grad():
    for data in testloader:
        images, labels = data
        # Move our data to GPU
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.4}%')
# Out:
# Accuracy of the network on the 10000 test images: 89.67%

# %% [markdown]
# ### **Training Plots**

# %%
import matplotlib.pyplot as plt

# To create a plot with secondary y-axis we need to create a subplot
fig, ax1 = plt.subplots()

# Set title and x-axis label rotation
plt.title("Accuracy & Loss vs Epoch Mini-Batches")
plt.xticks(rotation=45)

# We use twinx to create a plot a secondary y axis
ax2 = ax1.twinx()

# Create plot for loss_log and accuracy_log
ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, accuracy_log, 'b-')

# Set labels
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()
